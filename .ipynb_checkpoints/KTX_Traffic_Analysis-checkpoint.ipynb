# %%
import numpy as np
import pandas as pd 
from datetime import datetime
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data = pd.read_excel('datasets/Gyeongbu_HSR.xlsx')
data.head()
# Out:
#           Train  Number Departure Time Arrival Time Travel Time (Hours)  \
# 0           KTX       1       05:13:00     07:49:00            02:36:00
# 1           KTX       3       05:28:00     08:15:00            02:47:00
# 2           KTX       5       05:58:00     08:42:00            02:44:00
# 3  KTX-Sancheon      75       06:03:00     08:48:00            02:45:00
# 4           KTX       7       06:33:00     09:21:00            02:48:00
#
#                                                Stops  Cost (Korean Won)  \
# 0  Gwangmyeong, Daejeon, Dongdaegu, Gyeongju, Uls...              59800
# 1  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 2  Gwangmyeong, Cheonan-Asan, Daejeon, Seodaegu, ...              59400
# 3  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Gim...              59800
# 4  Gwangmyeong, Osong, Daejeon, Gimcheon-Gumi, Do...              59800
#
#    Cost (US Dollars) Additional Information
# 0             44.252               HSR ONLY
# 1             44.252               HSR ONLY
# 2             43.956               Seodaegu
# 3             44.252               HSR ONLY
# 4             44.252               HSR ONLY

# %%
def convert_to_hours(time_obj):
    # Extract hours and minutes
    hours = time_obj.hour
    minutes = time_obj.minute
    # Convert to total hours
    total_hours = hours + minutes / 60.0
    return round(total_hours,2)

# %%
# Apply the conversion function to the 'Travel Time' column and create a new column for hours
data['Travel Time (Hours)'] = data['Travel Time (Hours)'].apply(convert_to_hours)

# %%
data['ID'] = range(1, len(data) + 1)

# %%
data
# Out:
#               Train  Number Departure Time Arrival Time  Travel Time (Hours)  \
# 0               KTX       1       05:13:00     07:49:00                 2.60
# 1               KTX       3       05:28:00     08:15:00                 2.78
# 2               KTX       5       05:58:00     08:42:00                 2.73
# 3      KTX-Sancheon      75       06:03:00     08:48:00                 2.75
# 4               KTX       7       06:33:00     09:21:00                 2.80
# 5               KTX       9       06:57:00     09:38:00                 2.68
# 6               KTX      11       07:28:00     09:59:00                 2.52
# 7               KTX      13       07:50:00     10:25:00                 2.58
# 8               KTX      15       07:58:00     10:45:00                 2.78
# 9               KTX     121       08:12:00     11:32:00                 3.33
# 10     KTX-Sancheon     191       08:35:00     11:03:00                 2.47
# 11  KTX-Cheongryong      17       08:58:00     11:13:00                 2.25
# 12     KTX-Sancheon      19       09:28:00     12:16:00                 2.80
# 13              KTX     101       09:33:00     12:52:00                 3.32
# 14              KTX      21       09:58:00     12:45:00                 2.78
# 15              KTX     123       10:12:00     13:34:00                 3.37
# 16              KTX    4003       10:18:00     12:56:00                 2.63
# 17              KTX      23       10:28:00     13:13:00                 2.75
# 18              KTX      25       10:58:00     13:41:00                 2.72
# 19              KTX      27       11:58:00     14:41:00                 2.72
# 20              KTX      29       12:25:00     15:06:00                 2.68
# 21     KTX-Sancheon      31       12:58:00     15:43:00                 2.75
# 22              KTX     103       13:08:00     16:27:00                 3.32
# 23              KTX      33       13:18:00     15:58:00                 2.67
# 24              KTX     183       13:49:00     16:24:00                 2.58
# 25              KTX      35       13:58:00     16:34:00                 2.60
# 26              KTX     185       14:15:00     16:43:00                 2.47
# 27              KTX      37       14:19:00     16:49:00                 2.50
# 28     KTX-Sancheon      39       14:28:00     17:11:00                 2.72
# 29              KTX    4001       14:42:00     17:22:00                 2.67
# 30              KTX      41       14:58:00     17:47:00                 2.82
# 31              KTX    4007       15:19:00     18:37:00                 3.30
# 32              KTX      43       15:45:00     18:00:00                 2.25
# 33     KTX-Sancheon     193       15:50:00     18:20:00                 2.50
# 34              KTX      45       15:58:00     18:41:00                 2.72
# 35              KTX     125       16:02:00     19:20:00                 3.30
# 36              KTX      47       16:28:00     18:58:00                 2.50
# 37              KTX      49       16:58:00     19:46:00                 2.80
# 38              KTX     105       17:13:00     20:15:00                 3.03
# 39              KTX      51       17:23:00     20:11:00                 2.80
# 40              KTX      53       17:58:00     20:35:00                 2.62
# 41              KTX      55       18:13:00     20:54:00                 2.68
# 42              KTX      57       18:24:00     21:13:00                 2.82
# 43              KTX     107       18:41:00     22:05:00                 3.40
# 44              KTX     127       18:53:00     22:13:00                 3.33
# 45              KTX      59       18:58:00     21:38:00                 2.67
# 46              KTX      61       19:35:00     22:09:00                 2.57
# 47              KTX    4005       19:54:00     22:28:00                 2.57
# 48              KTX      63       19:58:00     22:37:00                 2.65
# 49     KTX-Sancheon     197       20:13:00     22:41:00                 2.47
# 50     KTX-Sancheon    9197       20:13:00     22:41:00                 2.47
# 51              KTX      65       20:28:00     23:00:00                 2.53
# 52              KTX     109       20:49:00     00:02:00                 3.22
# 53              KTX      67       20:58:00     23:45:00                 2.78
# 54              KTX      69       21:28:00     00:04:00                 2.60
# 55              KTX     111       21:38:00     00:47:00                 3.15
# 56              KTX      71       21:58:00     00:42:00                 2.73
# 57              KTX      73       22:28:00     01:03:00                 2.58
#
#                                                 Stops  Cost (Korean Won)  \
# 0   Gwangmyeong, Daejeon, Dongdaegu, Gyeongju, Uls...              59800
# 1   Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 2   Gwangmyeong, Cheonan-Asan, Daejeon, Seodaegu, ...              59400
# 3   Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Gim...              59800
# 4   Gwangmyeong, Osong, Daejeon, Gimcheon-Gumi, Do...              59800
# 5   Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 6              Gwangmyeong, Osong, Daejeon, Dongdaegu              59800
# 7   Gwangmyeong, Daejeon, Dongdaegu, Gyeongju, Uls...              59800
# 8   Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 9   Yeongdeungpo, Suwon, Daejeon, Dongdaegu, Gyeon...              48800
# 10                    Gwangmyeong, Daejeon, Dongdaegu              59800
# 11                                 Daejeon, Dongdaegu              59800
# 12  Gwangmyeong, Osong, Daejeon, Gimcheon-Gumi, Do...              59800
# 13  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Seo...              53500
# 14  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 15  Yeongdeungpo, Suwon, Daejeon, Dongdaegu, Gyeon...              48800
# 16  Cheonan-Asan, Osong, Daejeon, Gimcheon-Gumi, D...              59800
# 17  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Gim...              59800
# 18  Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu,...              59800
# 19  Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu,...              59800
# 20  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 21  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 22  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              53500
# 23  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 24  Gwangmyeong, Daejeon, Gimcheon-Gumi, Dongdaegu...              59800
# 25  Cheonan-Asan, Osong, Daejeon, Dongdaegu, Gyeongju              59800
# 26    Gwangmyeong, Daejeon, Gimcheon-Gumi, Dongdaegu               59800
# 27             Gwangmyeong, Osong, Daejeon, Dongdaegu              59800
# 28  Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu,...              59800
# 29  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 30  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 31  Yeongdeungpo, Suwon, Daejeon, Dongdaegu, Ulsan...              48800
# 32                                 Daejeon, Dongdaegu              60200
# 33               Daejeon, Dongdaegu, Ulsan (Tongdosa)              59800
# 34  Gwangmyeong, Daejeon, Gimcheon-Gumi, Seodaegu,...              59400
# 35  Yeongdeungpo, Suwon, Daejeon, Dongdaegu, Ulsan...              48800
# 36  Cheonan-Asan, Daejeon, Dongdaegu, Ulsan (Tongd...              59800
# 37  Gwangmyeong, Osong, Daejeon, Gimcheon-Gumi, Do...              59800
# 38  Gwangmyeong, Daejeon, Dongdaegu, Gyeongsan, Mi...              53900
# 39  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 40  Cheonan-Asan, Daejeon, Gimcheon-Gumi, Dongdaeg...              59800
# 41  Gwangmyeong, Osong, Daejeon, Gimcheon-Gumi, Do...              59800
# 42  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 43  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Gim...              53500
# 44  Yeongdeungpo, Suwon, Daejeon, Dongdaegu, Gyeongju              48800
# 45  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 46  Osong, Daejeon, Gimcheon-Gumi, Dongdaegu, Ulsa...              59800
# 47  Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu,...              59800
# 48  Gwangmyeong, Cheonan-Asan, Osong, Daejeon, Don...              59800
# 49      Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu              59800
# 50      Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu              59800
# 51     Daejeon, Seodaegu, Dongdaegu, Ulsan (Tongdosa)              59400
# 52  Gwangmyeong, Cheonan-Asan, Daejeon, Seodaegu, ...              53500
# 53  Gwangmyeong, Cheonan-Asan, Daejeon, Gimcheon-G...              59800
# 54  Gwangmyeong, Osong, Daejeon, Dongdaegu, Ulsan ...              59800
# 55  Gwangmyeong, Cheonan-Asan, Daejeon, Seodaegu, ...              53500
# 56  Gwangmyeong, Cheonan-Asan, Daejeon, Seodaegu, ...              59400
# 57  Gwangmyeong, Cheonan-Asan, Daejeon, Dongdaegu,...              59800
#
#     Cost (US Dollars) Additional Information  ID
# 0              44.252               HSR ONLY   1
# 1              44.252               HSR ONLY   2
# 2              43.956               Seodaegu   3
# 3              44.252               HSR ONLY   4
# 4              44.252               HSR ONLY   5
# 5              44.252               HSR ONLY   6
# 6              44.252               HSR ONLY   7
# 7              44.252               HSR ONLY   8
# 8              44.252               HSR ONLY   9
# 9              36.112                  Suwon  10
# 10             44.252               HSR ONLY  11
# 11             44.252               HSR ONLY  12
# 12             44.252               HSR ONLY  13
# 13             39.590         Seodaegu, Gupo  14
# 14             44.252               HSR ONLY  15
# 15             36.112                  Suwon  16
# 16             44.252               HSR ONLY  17
# 17             44.252               HSR ONLY  18
# 18             44.252               HSR ONLY  19
# 19             44.252               HSR ONLY  20
# 20             44.252               HSR ONLY  21
# 21             44.252               HSR ONLY  22
# 22             39.590         Seodaegu, Gupo  23
# 23             44.252               HSR ONLY  24
# 24             44.252               HSR ONLY  25
# 25             44.252               HSR ONLY  26
# 26             44.252               HSR ONLY  27
# 27             44.252               HSR ONLY  28
# 28             44.252               HSR ONLY  29
# 29             44.252               HSR ONLY  30
# 30             44.252               HSR ONLY  31
# 31             36.112                  Suwon  32
# 32             44.548               HSR ONLY  33
# 33             44.252               HSR ONLY  34
# 34             43.956               Seodaegu  35
# 35             36.112                  Suwon  36
# 36             44.252               HSR ONLY  37
# 37             44.252               HSR ONLY  38
# 38             39.886                   Gupo  39
# 39             44.252               HSR ONLY  40
# 40             44.252               HSR ONLY  41
# 41             44.252               HSR ONLY  42
# 42             44.252               HSR ONLY  43
# 43             39.590         Seodaegu, Gupo  44
# 44             36.112                  Suwon  45
# 45             44.252               HSR ONLY  46
# 46             44.252               HSR ONLY  47
# 47             44.252               HSR ONLY  48
# 48             44.252               HSR ONLY  49
# 49             44.252               HSR ONLY  50
# 50             44.252               HSR ONLY  51
# 51             43.956               Seodaegu  52
# 52             39.590         Seodaegu, Gupo  53
# 53             44.252               HSR ONLY  54
# 54             44.252               HSR ONLY  55
# 55             39.590         Seodaegu, Gupo  56
# 56             43.956               Seodaegu  57
# 57             44.252               HSR ONLY  58

# %%
stop_numbers = 0
for i in range(len(data['Stops'])):
    my_string = data['Stops'][i]
    my_list = my_string.split(",")
    print(my_list, len(my_list))
    stop_numbers += len(my_list)
# Out:
# ['Gwangmyeong', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Seodaegu', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Dongdaegu'] 4
# ['Gwangmyeong', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Yeongdeungpo', ' Suwon', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Daejeon', ' Dongdaegu'] 3
# ['Daejeon', ' Dongdaegu'] 2
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Seodaegu', ' Dongdaegu', ' Miryang', ' Mulgeum', ' Gupo'] 9
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Yeongdeungpo', ' Suwon', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 6
# ['Cheonan-Asan', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Gyeongju'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Seodaegu', ' Dongdaegu', ' Miryang', ' Mulgeum', ' Gupo'] 9
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Gyeongju'] 5
# ['Gwangmyeong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu '] 4
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Dongdaegu'] 4
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Gyeongju'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Yeongdeungpo', ' Suwon', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Daejeon', ' Dongdaegu'] 2
# ['Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 3
# ['Gwangmyeong', ' Daejeon', ' Gimcheon-Gumi', ' Seodaegu', ' Dongdaegu', ' Gyeongju'] 6
# ['Yeongdeungpo', ' Suwon', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 4
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Daejeon', ' Dongdaegu', ' Gyeongsan', ' Miryang', ' Gupo'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Gimcheon-Gumi', ' Seodaegu', ' Dongdaegu', ' Miryang', ' Mulgeum', ' Gupo'] 10
# ['Yeongdeungpo', ' Suwon', ' Daejeon', ' Dongdaegu', ' Gyeongju'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Osong', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Gyeongju'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Osong', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu'] 4
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu'] 4
# ['Daejeon', ' Seodaegu', ' Dongdaegu', ' Ulsan (Tongdosa)'] 4
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Seodaegu', ' Dongdaegu', ' Miryang', ' Mulgeum', ' Gupo'] 8
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Gimcheon-Gumi', ' Dongdaegu', ' Gyeongju', ' Ulsan (Tongdosa)'] 7
# ['Gwangmyeong', ' Osong', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Seodaegu', ' Dongdaegu', ' Miryang', ' Gupo'] 7
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Seodaegu', ' Dongdaegu', ' Ulsan (Tongdosa)'] 6
# ['Gwangmyeong', ' Cheonan-Asan', ' Daejeon', ' Dongdaegu', ' Ulsan (Tongdosa)'] 5

# %%
train_num = len(data['Stops'])
train_num
# Out:
# 58

# %%
average_stops = np.round(stop_numbers / train_num)
average_stops
# Out:
# 6.0

# %% [markdown]
# $ q = \frac{1}{\overline{h}} $
#
# - q is traffic flow measured in vehicles per hour
# - $\overline{h}$ is the average headway in hours

# %%
# Convert 'Departure Time' and 'Arrival Time' to datetime objects
data['Departure Time'] = pd.to_datetime(data['Departure Time'], format='%H:%M:%S')
data['Arrival Time'] = pd.to_datetime(data['Arrival Time'], format='%H:%M:%S')

# Calculate the time differences between stops
time_diff = 0
for i in range(len(data['Departure Time'])-50):
    dep_time = data['Departure Time'].iloc[i]
    next_dep_time = data['Departure Time'].iloc[i+1]
    print(f'next: {next_dep_time} current: {dep_time}')
    diff = (next_dep_time - dep_time).total_seconds() / 3600  # Convert seconds to hours
    print(f'diff: {diff*60}')
    time_diff += diff

print(f"Total time difference: {time_diff} hours")
# Out:
# next: 1900-01-01 05:28:00 current: 1900-01-01 05:13:00
# diff: 15.0
# next: 1900-01-01 05:58:00 current: 1900-01-01 05:28:00
# diff: 30.0
# next: 1900-01-01 06:03:00 current: 1900-01-01 05:58:00
# diff: 5.0
# next: 1900-01-01 06:33:00 current: 1900-01-01 06:03:00
# diff: 30.0
# next: 1900-01-01 06:57:00 current: 1900-01-01 06:33:00
# diff: 24.0
# next: 1900-01-01 07:28:00 current: 1900-01-01 06:57:00
# diff: 31.000000000000004
# next: 1900-01-01 07:50:00 current: 1900-01-01 07:28:00
# diff: 22.0
# next: 1900-01-01 07:58:00 current: 1900-01-01 07:50:00
# diff: 8.0
# Total time difference: 2.75 hours

# %%
average_headway_hours = time_diff / train_num
print(f'Average headway: {np.round(average_headway_hours,3)} hours')
print(f'Average headway: {np.round(average_headway_hours*60,3)} minutes')
# Out:
# Average headway: 0.047 hours
# Average headway: 2.845 minutes

# %%
q_flow = 1/average_headway_hours
print(f'Average Traffic Flow: {q_flow} trains per hour')
# Out:
# Average Traffic Flow: 21.090909090909093 trains per hour

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract the stops for the first train
stops = data.loc[0, 'Stops'].split(', ')
stop_distances = [0, 15, 100, 200, 300, 398.2]  # Example distances in km for each stop
total_distance = 398.2
cruise_speed = 300  # km/h
stop_time = 2 / 60  # hours per stop

# Create time and distance lists
time_points = [0]  # Start at time 0
distance_points = [0]  # Start at Seoul (0 km)

current_time = 0

for i in range(1, len(stop_distances)):
    # Calculate travel time to next stop
    travel_time = (stop_distances[i] - stop_distances[i - 1]) / cruise_speed
    current_time += travel_time
    time_points.append(current_time)
    distance_points.append(stop_distances[i])
    
    # Add stop time
    current_time += stop_time
    time_points.append(current_time)
    distance_points.append(stop_distances[i])

# Generate the plot
plt.figure(figsize=(10, 6))
plt.plot(time_points, distance_points, marker='o')
plt.xlabel('Time (hours)')
plt.ylabel('Distance from Seoul (km)')
plt.title('Train Trajectory from Seoul to Busan')
plt.grid(True)
plt.show()
